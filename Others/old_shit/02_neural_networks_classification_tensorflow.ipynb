# %% [markdown]
# # Introduction to neural network classification with TensorFlow
# - binary clasification (is this mail spam or not)
# [One thing or another], **1 or 0**
#
# - multiclass classification (is this cat, dog or cow)
# [More than one thing or another], **1 or x**, **One label per prediction**
#
# - multilabel classification (what tags should this article have), **Multiple labels per prediction**

# %% [markdown]
# # Create a data to view and fit

# %%
from sklearn.datasets import make_circles
import tensorflow as tf
import numpy as np

# make 1000 different examples
n_samples = 10000

# create circles
X, y = make_circles(n_samples,
                    noise=0.03,
                    random_state=42)

# %%
print(X[:10], "\n"*2, y[:10])
# Out:
# [[ 0.0464692   0.82477834]
#  [ 1.00506323 -0.43335153]
#  [-0.58348442  0.79452834]
#  [ 0.98478298 -0.32517879]
#  [ 0.82993028 -0.54722305]
#  [-0.13392877  0.77624858]
#  [ 0.77919743  0.64581132]
#  [ 0.72295477  0.17383084]
#  [-0.12180665  0.79695076]
#  [ 0.84952936  0.50567829]]
#
#  [1 0 0 0 0 1 0 1 1 0]

# %%
# visualise the cell below where certain indexes of dimensions are chosen (only for my info)
X[:, 0][:3]
# Out:
# array([ 0.0464692 ,  1.00506323, -0.58348442])

# %%
import pandas as pd

# create pandas sheet
circles = pd.DataFrame({"X0": X[:, 0], "X1": X[:, 1], "Label": y})
circles.head()
# Out:
#          X0        X1  Label
# 0  0.046469  0.824778      1
# 1  1.005063 -0.433352      0
# 2 -0.583484  0.794528      0
# 3  0.984783 -0.325179      0
# 4  0.829930 -0.547223      0

# %%
import matplotlib.pyplot as plt

# Visualise with plot, notice that "Create circles function" creates X and y coordinates for each point.
# Makes all those coordinates with distribution to the circle


# c = y really calls the y labels from above...
plt.figure(figsize=(10, 10))
plt.scatter(circles["X0"], circles["X1"], c=y, cmap=plt.cm.RdYlBu, marker=".")
plt.scatter(0.754246, 0.231481, color="orange")
_ = plt.scatter(-0.756159,	0.153259, color="orange")

# %% [markdown]
# # input and output shapes

# %%
X.shape, y.shape
# Out:
# ((10000, 2), (10000,))

# %% [markdown]
# # steps in modeling
# - create or import a model
# - compile the model
# - fit the model
# - evaluate the model
# - tweak
# - evaluate

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

print(X_train.shape)
len(X_train), len(X_test), len(y_train), len(y_test)


X_train_normalizer = tf.keras.layers.Normalization(input_shape=[2], axis=None)
X_train_normalizer.adapt(X_train)
# Out:
# (7000, 2)

# %%
# create a model
tf.random.set_seed(42)

model_1 = tf.keras.Sequential([X_train_normalizer,
                               tf.keras.layers.Dense(512, activation="relu"),
                               tf.keras.layers.Dense(512, activation="relu"),
                               tf.keras.layers.Dense(512, activation="relu"),
                               tf.keras.layers.Dense(512, activation="relu"),
                               tf.keras.layers.Dense(1, activation="sigmoid")
])

# compile the model
model_1.compile(loss=tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.000045),
                metrics="accuracy")

#lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch/20))

# fit the model
history_1 = model_1.fit(X_train, y_train, epochs=50, verbose=1, validation_split=0.15) #, callbacks=[lr_scheduler])
# Out:
# Epoch 1/50
# 186/186 [==============================] - 3s 15ms/step - loss: 0.6871 - accuracy: 0.4975 - val_loss: 0.6861 - val_accuracy: 0.4762
# Epoch 2/50
# 186/186 [==============================] - 3s 13ms/step - loss: 0.6753 - accuracy: 0.4997 - val_loss: 0.6643 - val_accuracy: 0.5590
# Epoch 3/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.5975 - accuracy: 0.7382 - val_loss: 0.4670 - val_accuracy: 0.9733
# Epoch 4/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.2486 - accuracy: 0.9908 - val_loss: 0.0942 - val_accuracy: 0.9990
# Epoch 5/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0524 - accuracy: 0.9985 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 6/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0216 - accuracy: 0.9997 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 7/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0151 - accuracy: 0.9985 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 8/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0097 - accuracy: 0.9993 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 9/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0079 - accuracy: 0.9995 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 10/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0056 - accuracy: 0.9995 - val_loss: 0.0056 - val_accuracy: 0.9990
# Epoch 11/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 12/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0045 - accuracy: 0.9997 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 13/50
# 186/186 [==============================] - 3s 13ms/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 0.0070 - val_accuracy: 0.9990
# Epoch 14/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0038 - accuracy: 0.9993 - val_loss: 0.0067 - val_accuracy: 0.9981
# Epoch 15/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0054 - val_accuracy: 0.9990
# Epoch 16/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 17/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.0076 - val_accuracy: 0.9981
# Epoch 18/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 19/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 20/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 21/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0128 - val_accuracy: 0.9943
# Epoch 22/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0058 - accuracy: 0.9973 - val_loss: 0.0025 - val_accuracy: 0.9990
# Epoch 23/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 24/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0077 - accuracy: 0.9968 - val_loss: 0.0092 - val_accuracy: 0.9971
# Epoch 25/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0045 - val_accuracy: 0.9990
# Epoch 26/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 27/50
# 186/186 [==============================] - 3s 13ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 28/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 29/50
# 186/186 [==============================] - 3s 13ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.0042 - val_accuracy: 0.9990
# Epoch 30/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0025 - val_accuracy: 0.9990
# Epoch 31/50
# 186/186 [==============================] - 3s 13ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.0061 - val_accuracy: 0.9971
# Epoch 32/50
# 186/186 [==============================] - 3s 14ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 33/50
# 186/186 [==============================] - 2s 13ms/step - loss: 8.7212e-04 - accuracy: 1.0000 - val_loss: 7.5771e-04 - val_accuracy: 1.0000
# Epoch 34/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 35/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0015 - val_accuracy: 0.9990
# Epoch 36/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0027 - val_accuracy: 0.9990
# Epoch 37/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0104 - val_accuracy: 0.9952
# Epoch 38/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.0020 - val_accuracy: 0.9990
# Epoch 39/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0074 - val_accuracy: 0.9971
# Epoch 40/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0081 - accuracy: 0.9966 - val_loss: 0.0031 - val_accuracy: 0.9981
# Epoch 41/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 6.2761e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 9.5926e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0022 - accuracy: 0.9988 - val_loss: 0.0109 - val_accuracy: 0.9943
# Epoch 44/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 4.9302e-04 - val_accuracy: 1.0000
# Epoch 45/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0036 - val_accuracy: 0.9981
# Epoch 46/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 47/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0108 - accuracy: 0.9955 - val_loss: 0.0135 - val_accuracy: 0.9962
# Epoch 48/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 49/50
# 186/186 [==============================] - 2s 13ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 5.3314e-04 - val_accuracy: 1.0000
# Epoch 50/50
# 186/186 [==============================] - 2s 13ms/step - loss: 5.1965e-04 - accuracy: 1.0000 - val_loss: 6.6801e-04 - val_accuracy: 1.0000

# %%
plt.figure(figsize=(15, 7))
plt.plot(history_1.history["accuracy"], label=("accuracy"))
plt.plot(history_1.history["loss"], label="loss")
plt.legend()
plt.grid(True)

# %%
plt.figure(figsize=(8, 8))
plt.plot(history_1.history["loss"])
plt.plot(history_1.history["val_loss"])
plt.grid(True)

# %%
pd.DataFrame(history_1.history).plot(figsize=(10,7), xlabel="epochs");

# %%
"""# Plot the learning rate versus the loss
lrs = 1e-4 * (10 ** (np.arange(26)/20))
plt.figure(figsize=(10, 7))
plt.semilogx(lrs, history_1.history["loss"]) # we want the x-axis (learning rate) to be log scale
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Learning rate vs. loss");"""
# Out:
# '# Plot the learning rate versus the loss\nlrs = 1e-4 * (10 ** (np.arange(26)/20))\nplt.figure(figsize=(10, 7))\nplt.semilogx(lrs, history_1.history["loss"]) # we want the x-axis (learning rate) to be log scale\nplt.xlabel("Learning Rate")\nplt.ylabel("Loss")\nplt.title("Learning rate vs. loss");'

# %%
from IPython.core.pylabtools import figsize
import numpy as np

def plot_decision_boundary(model, X, y):
  """
  Plots the decision boundary created by a model predicting on X.
  This function has been adapted from two phenomenal resources:
   1. CS231n - https://cs231n.github.io/neural-networks-case-study/
   2. Made with ML basics - https://github.com/GokuMohandas/MadeWithML/blob/main/notebooks/08_Neural_Networks.ipynb
  """
  # Define the axis boundaries of the plot and create a meshgrid
  x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
  y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
  xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                       np.linspace(y_min, y_max, 100))
  
  # Create X values (we're going to predict on all of these)
  x_in = np.c_[xx.ravel(), yy.ravel()] # stack 2D arrays together: https://numpy.org/devdocs/reference/generated/numpy.c_.html
  
  # Make predictions using the trained model
  y_pred = model.predict(x_in)

  # Check for multi-class
  if len(y_pred[0]) > 1:
    print("doing multiclass classification...")
    # We have to reshape our predictions to get them ready for plotting
    y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
  else:
    print("doing binary classifcation...")
    y_pred = np.round(y_pred).reshape(xx.shape)
  
  # Plot decision boundary
  plt.figure(figsize=(15, 15))
  plt.grid(True)
  plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
  plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
  plt.xticks(np.arange(-1., 1., 0.1))
  plt.yticks(np.arange(-1., 1., 0.1))
  plt.xlim(xx.min(), xx.max())
  plt.ylim(yy.min(), yy.max())

# %%
plot_decision_boundary(model_1, X, y)
# Out:
# doing binary classifcation...

# %%
# evaluate on original data
model_1.evaluate(X_test, y_test)
# Out:
# 94/94 [==============================] - 0s 4ms/step - loss: 9.0560e-04 - accuracy: 0.9997
# [0.0009055954869836569, 0.999666690826416]

# %%
X, y = make_circles(n_samples,
                    noise=0.03,
                    random_state=100)

# %%
# evaluate on new features and labels
model_1.evaluate(X, y)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0017 - accuracy: 0.9996
# [0.0016579012153670192, 0.9995999932289124]

# %%
# Check out the predictions our model is making 
plot_decision_boundary(model_1, X, y)
# Out:
# doing binary classifcation...
