# %%
import requests
from io import BytesIO  # buffer for reading data in bytes
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("images/ada_boost.png")
plt.style.use("default")
plt.figure(figsize=(16, 9))
plt.imshow(img)
plt.show()
